# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from PIL import Image
import cv2

# %%
saved_model = tf.keras.models.load_model('/content/drive/MyDrive/project_saved/veg_classifier.h5')

# %%
im=Image.open("/content/drive/MyDrive/project_saved/image2.jpg")
gray_scale=cv2.cvtColor(np.float32(im),cv2.COLOR_BGR2GRAY)
gray=cv2.resize(gray_scale,(100,100))
plt.imshow(im)
plt.axis("off")
im=np.expand_dims(gray,axis=0)
im=np.array(im)
im=np.reshape(im,(1,100,100,1))
predict=saved_model.predict(im)
category=np.argmax(predict,axis=1)
if category[0]==0:
  print('fresh_apple')
elif category[0]==1:
  print('stale_banana')
elif category[0]==2:
  print('stale_apple')
elif category[0]==3:
  print('stale_capsicum')
elif category[0]==4:
  print('stale_tomato')
elif category[0]==5:
  print('fresh_bitter_gourd')
elif category[0]==6:
  print('fresh_capsicum')
elif category[0]==7:
  print('fresh_orange')
elif category[0]==8:
  print('fresh_tomato')
elif category[0]==9:
  print('stale_bitter_gourd')
elif category[0]==10:
  print('stale_orange')
else:
  print('fresh_banana')
# Out:
# fresh_banana

# %%
im=Image.open("/content/drive/MyDrive/APPLE_DATASET/FRESH/rotated_by_15_Screen Shot 2018-06-08 at 4.59.36 PM.png")
gray_scale=cv2.cvtColor(np.float32(im),cv2.COLOR_BGR2GRAY)
gray=cv2.resize(gray_scale,(100,100))
plt.imshow(im)
plt.axis("off")
im=np.expand_dims(gray,axis=0)
im=np.array(im)
im=np.reshape(im,(1,100,100,1))
predict=saved_model.predict(im)
category=np.argmax(predict,axis=1)
if category[0]==0:
  print('fresh_apple')
elif category[0]==1:
  print('stale_banana')
elif category[0]==2:
  print('stale_apple')
elif category[0]==3:
  print('stale_capsicum')
elif category[0]==4:
  print('stale_tomato')
elif category[0]==5:
  print('fresh_bitter_gourd')
elif category[0]==6:
  print('fresh_capsicum')
elif category[0]==7:
  print('fresh_orange')
elif category[0]==8:
  print('fresh_tomato')
elif category[0]==9:
  print('stale_bitter_gourd')
elif category[0]==10:
  print('stale_orange')
else:
  print('fresh_banana')
# Out:
# fresh_apple

# %%
im=Image.open("/content/drive/MyDrive/Project_dataset/stale_bitter_gourd/IMG_20200824_182208.jpg_0_4242.jpg")
gray_scale=cv2.cvtColor(np.float32(im),cv2.COLOR_BGR2GRAY)
gray=cv2.resize(gray_scale,(100,100))
plt.imshow(im)
plt.axis("off")
im=np.expand_dims(gray,axis=0)
im=np.array(im)
im=np.reshape(im,(1,100,100,1))
predict=saved_model.predict(im)
category=np.argmax(predict,axis=1)
if category[0]==1:
  print('fresh_apple')
elif category[0]==2:
  print('stale_banana')
elif category[0]==3:
  print('stale_apple')
elif category[0]==4:
  print('stale_capsicum')
elif category[0]==5:
  print('stale_tomato')
elif category[0]==6:
  print('fresh_bitter_gourd')
elif category[0]==7:
  print('fresh_capsicum')
elif category[0]==8:
  print('fresh_orange')
elif category[0]==9:
  print('fresh_tomato')
elif category[0]==10:
  print('stale_orange')
elif category[0]==11:
  print('stale_bitter_gourd')
else:
  print('fresh_banana')
# Out:
# stale_bitter_gourd
